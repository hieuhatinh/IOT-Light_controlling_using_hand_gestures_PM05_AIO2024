# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("../hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label))
        )
        
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob, dim=1)
        return torch.where(softmax_prob[0,chosen_ind] > threshold,chosen_ind,-1)

    def predict_with_known_class(self, x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob, dim=1)

    def score(self,logits):
        return -torch.amax(logits, dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path, "r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False, max_num_hands=1, min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x, landmark.y, landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H_%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number, data in enumerate(trainloader):
            inputs,labels = data

            # reset gradients, dự đoán class cử chỉ của inputs
            optimizer.zero_grad()
            preds = model(inputs)
            
            # tính loss, backward và update parameters
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="../data_collection/data2/"
LIST_LABEL = label_dict_from_config_file("../hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH, "landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH, "landmark_val.csv")
save_path = '.'
os.makedirs(save_path, exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True, drop_last=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset, batch_size=50, shuffle=False, drop_last=True)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=20, min_delta=0.1)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.2838541567325592, val:0.4092307686805725
# LOSS train 1.5859229440490406 valid 1.5592068983958318
# Training vs. Validation Loss {'Training': 1.5859229440490406, 'Validation': 1.5592068983958318} 1
# Training vs. Validation accuracy {'Training': 0.2838541567325592, 'Validation': 0.4092307686805725} 1
# Epoch 1:
# Accuracy train:0.44583332538604736, val:0.6630769371986389
# LOSS train 1.5219676072398822 valid 1.4548449241198027
# Training vs. Validation Loss {'Training': 1.5219676072398822, 'Validation': 1.4548449241198027} 2
# Training vs. Validation accuracy {'Training': 0.44583332538604736, 'Validation': 0.6630769371986389} 2
# Epoch 2:
# Accuracy train:0.5989583134651184, val:0.892307698726654
# LOSS train 1.3691487063964207 valid 1.2045759421128492
# Training vs. Validation Loss {'Training': 1.3691487063964207, 'Validation': 1.2045759421128492} 3
# Training vs. Validation accuracy {'Training': 0.5989583134651184, 'Validation': 0.892307698726654} 3
# Epoch 3:
# Accuracy train:0.699999988079071, val:0.8830769062042236
# LOSS train 1.0672875332335632 valid 0.7760171156663161
# Training vs. Validation Loss {'Training': 1.0672875332335632, 'Validation': 0.7760171156663161} 4
# Training vs. Validation accuracy {'Training': 0.699999988079071, 'Validation': 0.8830769062042236} 4
# Epoch 4:
# Accuracy train:0.8098958134651184, val:0.9646154046058655
# LOSS train 0.7210749251147112 valid 0.40936534393292207
# Training vs. Validation Loss {'Training': 0.7210749251147112, 'Validation': 0.40936534393292207} 5
# Training vs. Validation accuracy {'Training': 0.8098958134651184, 'Validation': 0.9646154046058655} 5
# Epoch 5:
# Accuracy train:0.9083333611488342, val:0.9876922965049744
# LOSS train 0.4518162726114194 valid 0.19172465142149192
# Training vs. Validation Loss {'Training': 0.4518162726114194, 'Validation': 0.19172465142149192} 6
# Training vs. Validation accuracy {'Training': 0.9083333611488342, 'Validation': 0.9876922965049744} 6
# Epoch 6:
# Accuracy train:0.9619791507720947, val:1.0
# LOSS train 0.25138133733222884 valid 0.0604476838802489
# Training vs. Validation Loss {'Training': 0.25138133733222884, 'Validation': 0.0604476838802489} 7
# Training vs. Validation accuracy {'Training': 0.9619791507720947, 'Validation': 1.0} 7
# Epoch 7:
# Accuracy train:0.9802083373069763, val:1.0
# LOSS train 0.14761436994497976 valid 0.016919164631802302
# Training vs. Validation Loss {'Training': 0.14761436994497976, 'Validation': 0.016919164631802302} 8
# Training vs. Validation accuracy {'Training': 0.9802083373069763, 'Validation': 1.0} 8
# Epoch 8:
# Accuracy train:0.9947916865348816, val:1.0
# LOSS train 0.09188247293544312 valid 0.005880632874323055
# Training vs. Validation Loss {'Training': 0.09188247293544312, 'Validation': 0.005880632874323055} 9
# Training vs. Validation accuracy {'Training': 0.9947916865348816, 'Validation': 1.0} 9
# Epoch 9:
# Accuracy train:0.9958333373069763, val:1.0
# LOSS train 0.05165592522826046 valid 0.0028385327828940577
# Training vs. Validation Loss {'Training': 0.05165592522826046, 'Validation': 0.0028385327828940577} 10
# Training vs. Validation accuracy {'Training': 0.9958333373069763, 'Validation': 1.0} 10
# Epoch 10:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.04453649142912278 valid 0.001243225760005701
# Training vs. Validation Loss {'Training': 0.04453649142912278, 'Validation': 0.001243225760005701} 11
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 11
# Epoch 11:
# Accuracy train:0.996874988079071, val:1.0
# LOSS train 0.03314937786975255 valid 0.0008710097508110965
# Training vs. Validation Loss {'Training': 0.03314937786975255, 'Validation': 0.0008710097508110965} 12
# Training vs. Validation accuracy {'Training': 0.996874988079071, 'Validation': 1.0} 12
# Epoch 12:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.027782173119097326 valid 0.0005173398469476245
# Training vs. Validation Loss {'Training': 0.027782173119097326, 'Validation': 0.0005173398469476245} 13
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 13
# Epoch 13:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.021569844141292076 valid 0.0002965795501950197
# Training vs. Validation Loss {'Training': 0.021569844141292076, 'Validation': 0.0002965795501950197} 14
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 14
# Epoch 14:
# Accuracy train:0.996874988079071, val:1.0
# LOSS train 0.018663305910498213 valid 0.000197842725006362
# Training vs. Validation Loss {'Training': 0.018663305910498213, 'Validation': 0.000197842725006362} 15
# Training vs. Validation accuracy {'Training': 0.996874988079071, 'Validation': 1.0} 15
# Epoch 15:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.017353894140493747 valid 0.00010980312603910883
# Training vs. Validation Loss {'Training': 0.017353894140493747, 'Validation': 0.00010980312603910883} 16
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 16
# Epoch 16:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.018482415393615764 valid 9.967739354648914e-05
# Training vs. Validation Loss {'Training': 0.018482415393615764, 'Validation': 9.967739354648914e-05} 17
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 17
# Epoch 17:
# Accuracy train:1.0, val:1.0
# LOSS train 0.01231233986133399 valid 6.661801671725698e-05
# Training vs. Validation Loss {'Training': 0.01231233986133399, 'Validation': 6.661801671725698e-05} 18
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 18
# Epoch 18:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.011489946739554094 valid 4.73121803084863e-05
# Training vs. Validation Loss {'Training': 0.011489946739554094, 'Validation': 4.73121803084863e-05} 19
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 19
# Epoch 19:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.008822676076912709 valid 4.11269982648194e-05
# Training vs. Validation Loss {'Training': 0.008822676076912709, 'Validation': 4.11269982648194e-05} 20
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 20
# Epoch 20:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.011126249368923405 valid 3.986839215031068e-05
# Training vs. Validation Loss {'Training': 0.011126249368923405, 'Validation': 3.986839215031068e-05} 21
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 21
# Epoch 21:
# Accuracy train:0.9973958134651184, val:1.0
# LOSS train 0.0078060111942856265 valid 3.2872101271025785e-05
# Training vs. Validation Loss {'Training': 0.0078060111942856265, 'Validation': 3.2872101271025785e-05} 22
# Training vs. Validation accuracy {'Training': 0.9973958134651184, 'Validation': 1.0} 22
# Epoch 22:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.012397480645934897 valid 4.2722552349844664e-05
# Training vs. Validation Loss {'Training': 0.012397480645934897, 'Validation': 4.2722552349844664e-05} 23
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 23
# Epoch 23:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00917418390357246 valid 6.278098491153427e-05
# Training vs. Validation Loss {'Training': 0.00917418390357246, 'Validation': 6.278098491153427e-05} 24
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 24
# Epoch 24:
# Accuracy train:1.0, val:1.0
# LOSS train 0.007732366454244281 valid 1.4242360293792444e-05
# Training vs. Validation Loss {'Training': 0.007732366454244281, 'Validation': 1.4242360293792444e-05} 25
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 25
# Epoch 25:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.009835106415266637 valid 2.472921418162654e-05
# Training vs. Validation Loss {'Training': 0.009835106415266637, 'Validation': 2.472921418162654e-05} 26
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 26
# Epoch 26:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.006181611882008535 valid 1.7030022543342337e-05
# Training vs. Validation Loss {'Training': 0.006181611882008535, 'Validation': 1.7030022543342337e-05} 27
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 27
# Epoch 27:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.011347794217726914 valid 1.4345903196044674e-05
# Training vs. Validation Loss {'Training': 0.011347794217726914, 'Validation': 1.4345903196044674e-05} 28
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 28
# Epoch 28:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.008051608459936688 valid 1.098783409448655e-05
# Training vs. Validation Loss {'Training': 0.008051608459936688, 'Validation': 1.098783409448655e-05} 29
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 29
# Epoch 29:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.005090031700698698 valid 7.971539835475247e-06
# Training vs. Validation Loss {'Training': 0.005090031700698698, 'Validation': 7.971539835475247e-06} 30
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 30
# Epoch 30:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.007592753755185792 valid 1.098450463114904e-05
# Training vs. Validation Loss {'Training': 0.007592753755185792, 'Validation': 1.098450463114904e-05} 31
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 31
# Epoch 31:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004347960054171078 valid 6.396167402901763e-06
# Training vs. Validation Loss {'Training': 0.004347960054171078, 'Validation': 6.396167402901763e-06} 32
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 32
# Epoch 32:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0034907029469953463 valid 6.861769677995583e-06
# Training vs. Validation Loss {'Training': 0.0034907029469953463, 'Validation': 6.861769677995583e-06} 33
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 33
# Epoch 33:
# Accuracy train:1.0, val:1.0
# LOSS train 0.004502367795187941 valid 3.0271721457735953e-06
# Training vs. Validation Loss {'Training': 0.004502367795187941, 'Validation': 3.0271721457735953e-06} 34
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 34
# Epoch 34:
# Accuracy train:0.9973958134651184, val:1.0
# LOSS train 0.01021911327673782 valid 1.0120836035499591e-05
# Training vs. Validation Loss {'Training': 0.01021911327673782, 'Validation': 1.0120836035499591e-05} 35
# Training vs. Validation accuracy {'Training': 0.9973958134651184, 'Validation': 1.0} 35
# Epoch 35:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.01009150625395705 valid 7.5586813247460105e-06
# Training vs. Validation Loss {'Training': 0.01009150625395705, 'Validation': 7.5586813247460105e-06} 36
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 36
# Epoch 36:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003057189143873984 valid 4.595583299340853e-06
# Training vs. Validation Loss {'Training': 0.003057189143873984, 'Validation': 4.595583299340853e-06} 37
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 37
# Epoch 37:
# Accuracy train:1.0, val:1.0
# LOSS train 0.004002828700322425 valid 6.554981183626296e-06
# Training vs. Validation Loss {'Training': 0.004002828700322425, 'Validation': 6.554981183626296e-06} 38
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 38
# Epoch 38:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004547378415433438 valid 8.140019045955481e-06
# Training vs. Validation Loss {'Training': 0.004547378415433438, 'Validation': 8.140019045955481e-06} 39
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 39
# Epoch 39:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003843861658121265 valid 5.923920219594527e-06
# Training vs. Validation Loss {'Training': 0.003843861658121265, 'Validation': 5.923920219594527e-06} 40
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 40
# Epoch 40:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.004425630006153369 valid 6.144689199170618e-06
# Training vs. Validation Loss {'Training': 0.004425630006153369, 'Validation': 6.144689199170618e-06} 41
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 41
# Epoch 41:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.0026021108496934175 valid 2.337775708401051e-06
# Training vs. Validation Loss {'Training': 0.0026021108496934175, 'Validation': 2.337775708401051e-06} 42
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 42
# Epoch 42:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003505579436023254 valid 1.947324331187981e-06
# Training vs. Validation Loss {'Training': 0.003505579436023254, 'Validation': 1.947324331187981e-06} 43
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 43
# Epoch 43:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.005274287659631227 valid 2.7449079136833743e-06
# Training vs. Validation Loss {'Training': 0.005274287659631227, 'Validation': 2.7449079136833743e-06} 44
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002288268640768365 valid 2.871082298401444e-06
# Training vs. Validation Loss {'Training': 0.002288268640768365, 'Validation': 2.871082298401444e-06} 45
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 45
# Epoch 45:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.005852771068930451 valid 4.369620683064568e-06
# Training vs. Validation Loss {'Training': 0.005852771068930451, 'Validation': 4.369620683064568e-06} 46
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 46
# Epoch 46:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0066586892486763345 valid 6.078755323922171e-06
# Training vs. Validation Loss {'Training': 0.0066586892486763345, 'Validation': 6.078755323922171e-06} 47
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 47
# Epoch 47:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.0051449964948915294 valid 6.873564334324118e-06
# Training vs. Validation Loss {'Training': 0.0051449964948915294, 'Validation': 6.873564334324118e-06} 48
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 48
# Epoch 48:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.010827389558471623 valid 4.610773369397346e-06
# Training vs. Validation Loss {'Training': 0.010827389558471623, 'Validation': 4.610773369397346e-06} 49
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 49
# Epoch 49:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.008128433613819652 valid 6.750491353867661e-06
# Training vs. Validation Loss {'Training': 0.008128433613819652, 'Validation': 6.750491353867661e-06} 50
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 50
# Epoch 50:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0026788943493253705 valid 3.289039279562845e-06
# Training vs. Validation Loss {'Training': 0.0026788943493253705, 'Validation': 3.289039279562845e-06} 51
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 51
# Epoch 51:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002508638531253382 valid 1.585112115138215e-06
# Training vs. Validation Loss {'Training': 0.002508638531253382, 'Validation': 1.585112115138215e-06} 52
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 52
# Epoch 52:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017112175013001736 valid 1.6625022878358209e-06
# Training vs. Validation Loss {'Training': 0.0017112175013001736, 'Validation': 1.6625022878358209e-06} 53
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 53
# Epoch 53:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0030325925563374767 valid 2.635055232338765e-06
# Training vs. Validation Loss {'Training': 0.0030325925563374767, 'Validation': 2.635055232338765e-06} 54
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 54
# Epoch 54:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002644296424326361 valid 7.014442734415e-06
# Training vs. Validation Loss {'Training': 0.002644296424326361, 'Validation': 7.014442734415e-06} 55
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 55
# Epoch 55:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0063131324253239045 valid 2.564809338314087e-06
# Training vs. Validation Loss {'Training': 0.0063131324253239045, 'Validation': 2.564809338314087e-06} 56
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 56
# Epoch 56:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0024906256599024346 valid 2.201133443581791e-06
# Training vs. Validation Loss {'Training': 0.0024906256599024346, 'Validation': 2.201133443581791e-06} 57
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 57
# Epoch 57:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0019837337989277635 valid 1.1398212682077149e-06
# Training vs. Validation Loss {'Training': 0.0019837337989277635, 'Validation': 1.1398212682077149e-06} 58
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 58
# Epoch 58:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003422466979979314 valid 2.8565988498413094e-06
# Training vs. Validation Loss {'Training': 0.003422466979979314, 'Validation': 2.8565988498413094e-06} 59
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 59
# Epoch 59:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0032122010502462217 valid 1.5999650960688646e-06
# Training vs. Validation Loss {'Training': 0.0032122010502462217, 'Validation': 1.5999650960688646e-06} 60
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 60
# Epoch 60:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.004975961979956385 valid 1.8567250120983003e-06
# Training vs. Validation Loss {'Training': 0.004975961979956385, 'Validation': 1.8567250120983003e-06} 61
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 61
# Epoch 61:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0057201039004818694 valid 1.6337109738191639e-06
# Training vs. Validation Loss {'Training': 0.0057201039004818694, 'Validation': 1.6337109738191639e-06} 62
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 62
# Epoch 62:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0013984427878313 valid 9.169927417054588e-07
# Training vs. Validation Loss {'Training': 0.0013984427878313, 'Validation': 9.169927417054588e-07} 63
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 63
# Epoch 63:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0015102410923949112 valid 7.38363214159731e-07
# Training vs. Validation Loss {'Training': 0.0015102410923949112, 'Validation': 7.38363214159731e-07} 64
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 64
# Epoch 64:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009281709759155395 valid 9.06904988816028e-07
# Training vs. Validation Loss {'Training': 0.0009281709759155395, 'Validation': 9.06904988816028e-07} 65
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 65
# Epoch 65:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0018699987561679639 valid 9.901689699959732e-07
# Training vs. Validation Loss {'Training': 0.0018699987561679639, 'Validation': 9.901689699959732e-07} 66
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 66
# Epoch 66:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0012147409846268904 valid 6.831599045780806e-07
# Training vs. Validation Loss {'Training': 0.0012147409846268904, 'Validation': 6.831599045780806e-07} 67
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 67
# Epoch 67:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001550220343536542 valid 3.867878744128024e-07
# Training vs. Validation Loss {'Training': 0.001550220343536542, 'Validation': 3.867878744128024e-07} 68
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 68
# Epoch 68:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.001630882082811998 valid 3.4302162950937945e-05
# Training vs. Validation Loss {'Training': 0.001630882082811998, 'Validation': 3.4302162950937945e-05} 69
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 69
# Epoch 69:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0022708545698151283 valid 9.314802694641107e-07
# Training vs. Validation Loss {'Training': 0.0022708545698151283, 'Validation': 9.314802694641107e-07} 70
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 70
# Epoch 70:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0017379651083804977 valid 9.37164832984868e-07
# Training vs. Validation Loss {'Training': 0.0017379651083804977, 'Validation': 9.37164832984868e-07} 71
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 71
# Epoch 71:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003405124232358503 valid 2.659967515993545e-06
# Training vs. Validation Loss {'Training': 0.003405124232358503, 'Validation': 2.659967515993545e-06} 72
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 72
# Epoch 72:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0014915895932669325 valid 8.570203063457554e-07
# Training vs. Validation Loss {'Training': 0.0014915895932669325, 'Validation': 8.570203063457554e-07} 73
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 73
# Epoch 73:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0024875224927806507 valid 1.1847483582217733e-06
# Training vs. Validation Loss {'Training': 0.0024875224927806507, 'Validation': 1.1847483582217733e-06} 74
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 74
# Epoch 74:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012212376866500563 valid 4.83805604570073e-07
# Training vs. Validation Loss {'Training': 0.0012212376866500563, 'Validation': 4.83805604570073e-07} 75
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 75
# Epoch 75:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0015765854141136515 valid 7.440473970960354e-07
# Training vs. Validation Loss {'Training': 0.0015765854141136515, 'Validation': 7.440473970960354e-07} 76
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 76
# Epoch 76:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000986158841442375 valid 7.257073530826557e-07
# Training vs. Validation Loss {'Training': 0.000986158841442375, 'Validation': 7.257073530826557e-07} 77
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 77
# Epoch 77:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005457558234430356 valid 3.660638077790806e-07
# Training vs. Validation Loss {'Training': 0.0005457558234430356, 'Validation': 3.660638077790806e-07} 78
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 78
# Epoch 78:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0013806641605166685 valid 3.847703163947139e-07
# Training vs. Validation Loss {'Training': 0.0013806641605166685, 'Validation': 3.847703163947139e-07} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 79
# Epoch 79:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0012684622258802847 valid 2.5364043556062546e-07
# Training vs. Validation Loss {'Training': 0.0012684622258802847, 'Validation': 2.5364043556062546e-07} 80
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 80
# Epoch 80:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003173065778431313 valid 5.9696069542361296e-05
# Training vs. Validation Loss {'Training': 0.003173065778431313, 'Validation': 5.9696069542361296e-05} 81
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 81
# Epoch 81:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.0055392760918948625 valid 4.572126626702409e-07
# Training vs. Validation Loss {'Training': 0.0055392760918948625, 'Validation': 4.572126626702409e-07} 82
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 82
# Epoch 82:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0033586569569100297 valid 4.2365085183549723e-07
# Training vs. Validation Loss {'Training': 0.0033586569569100297, 'Validation': 4.2365085183549723e-07} 83
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 83
# Epoch 83:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006070606330771019 valid 6.015459785675586e-07
# Training vs. Validation Loss {'Training': 0.0006070606330771019, 'Validation': 6.015459785675586e-07} 84
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 84
# Epoch 84:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006553433522261306 valid 4.174145878174876e-07
# Training vs. Validation Loss {'Training': 0.0006553433522261306, 'Validation': 4.174145878174876e-07} 85
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 85
# Epoch 85:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0008562856701246346 valid 2.661113990361977e-07
# Training vs. Validation Loss {'Training': 0.0008562856701246346, 'Validation': 2.661113990361977e-07} 86
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 86
# Epoch 86:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011041861441754008 valid 3.1196113835763896e-07
# Training vs. Validation Loss {'Training': 0.0011041861441754008, 'Validation': 3.1196113835763896e-07} 87
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 87
# Epoch 87:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0006944013855445519 valid 1.437846753796853e-07
# Training vs. Validation Loss {'Training': 0.0006944013855445519, 'Validation': 1.437846753796853e-07} 88
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 88
# Epoch 88:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0010705670873297397 valid 2.3786817520816e-07
# Training vs. Validation Loss {'Training': 0.0010705670873297397, 'Validation': 2.3786817520816e-07} 89
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 89
# Epoch 89:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.006192714899422451 valid 4.962756574578009e-07
# Training vs. Validation Loss {'Training': 0.006192714899422451, 'Validation': 4.962756574578009e-07} 90
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 90
# Epoch 90:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007931360659843752 valid 4.775696471444218e-07
# Training vs. Validation Loss {'Training': 0.0007931360659843752, 'Validation': 4.775696471444218e-07} 91
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 91
# Epoch 91:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.005453040262636932 valid 2.181767727576628e-06
# Training vs. Validation Loss {'Training': 0.005453040262636932, 'Validation': 2.181767727576628e-06} 92
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 92
# Epoch 92:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002616334358738944 valid 2.1182561373332368e-07
# Training vs. Validation Loss {'Training': 0.002616334358738944, 'Validation': 2.1182561373332368e-07} 93
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 93
# Epoch 93:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0015667830356657457 valid 2.5272356105268466e-07
# Training vs. Validation Loss {'Training': 0.0015667830356657457, 'Validation': 2.5272356105268466e-07} 94
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 94
# Epoch 94:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.003152585348213203 valid 3.07192815048788e-07
# Training vs. Validation Loss {'Training': 0.003152585348213203, 'Validation': 3.07192815048788e-07} 95
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 95
# Epoch 95:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0015131462696065985 valid 2.743645097780245e-07
# Training vs. Validation Loss {'Training': 0.0015131462696065985, 'Validation': 2.743645097780245e-07} 96
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 96
# Epoch 96:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0011639889755012216 valid 3.0059027759184926e-07
# Training vs. Validation Loss {'Training': 0.0011639889755012216, 'Validation': 3.0059027759184926e-07} 97
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 97
# Epoch 97:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012227485014288202 valid 1.4947002405016553e-07
# Training vs. Validation Loss {'Training': 0.0012227485014288202, 'Validation': 1.4947002405016553e-07} 98
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 98
# Epoch 98:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002284369389675097 valid 1.513040594694268e-07
# Training vs. Validation Loss {'Training': 0.002284369389675097, 'Validation': 1.513040594694268e-07} 99
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 99
# Epoch 99:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0014067566655739938 valid 4.034764197277022e-07
# Training vs. Validation Loss {'Training': 0.0014067566655739938, 'Validation': 4.034764197277022e-07} 100
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 100
# Epoch 100:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005049043390954466 valid 2.747312411070897e-07
# Training vs. Validation Loss {'Training': 0.0005049043390954466, 'Validation': 2.747312411070897e-07} 101
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 101
# Epoch 101:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0015712408830192242 valid 1.8466032701579793e-06
# Training vs. Validation Loss {'Training': 0.0015712408830192242, 'Validation': 1.8466032701579793e-06} 102
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 102
# Epoch 102:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0016571792462703645 valid 3.046252535691215e-07
# Training vs. Validation Loss {'Training': 0.0016571792462703645, 'Validation': 3.046252535691215e-07} 103
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 103
# Epoch 103:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0019731196810350107 valid 2.747313433159294e-07
# Training vs. Validation Loss {'Training': 0.0019731196810350107, 'Validation': 2.747313433159294e-07} 104
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 104
# Epoch 104:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0004520491660287007 valid 1.9220196634250897e-07
# Training vs. Validation Loss {'Training': 0.0004520491660287007, 'Validation': 1.9220196634250897e-07} 105
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 105
# Epoch 105:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009509599960135043 valid 2.2136227182902354e-07
# Training vs. Validation Loss {'Training': 0.0009509599960135043, 'Validation': 2.2136227182902354e-07} 106
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 106
# Epoch 106:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001418445296394566 valid 1.6359173352716775e-07
# Training vs. Validation Loss {'Training': 0.001418445296394566, 'Validation': 1.6359173352716775e-07} 107
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 107
# Epoch 107:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0006819821785105281 valid 1.3296416166387923e-07
# Training vs. Validation Loss {'Training': 0.0006819821785105281, 'Validation': 1.3296416166387923e-07} 108
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 108
# Epoch 108:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0003568709651062818 valid 2.2558025136731885e-07
# Training vs. Validation Loss {'Training': 0.0003568709651062818, 'Validation': 2.2558025136731885e-07} 109
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 109
# Epoch 109:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001447676901534578 valid 2.5602445018736176e-07
# Training vs. Validation Loss {'Training': 0.001447676901534578, 'Validation': 2.5602445018736176e-07} 110
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 110
# Epoch 110:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004701676596141624 valid 1.5240436987631676e-07
# Training vs. Validation Loss {'Training': 0.0004701676596141624, 'Validation': 1.5240436987631676e-07} 111
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 111
# Epoch 111:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0008908439453231646 valid 1.1664164471898613e-07
# Training vs. Validation Loss {'Training': 0.0008908439453231646, 'Validation': 1.1664164471898613e-07} 112
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 112
# Epoch 112:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005090376837794489 valid 1.2489457208612993e-07
# Training vs. Validation Loss {'Training': 0.0005090376837794489, 'Validation': 1.2489457208612993e-07} 113
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 113
# Epoch 113:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00034175228525631 valid 1.7844683614525863e-07
# Training vs. Validation Loss {'Training': 0.00034175228525631, 'Validation': 1.7844683614525863e-07} 114
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 114
# Epoch 114:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002968999982897458 valid 8.326306208608422e-08
# Training vs. Validation Loss {'Training': 0.0002968999982897458, 'Validation': 8.326306208608422e-08} 115
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 115
# Epoch 115:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.004721215295300378 valid 9.316483797761066e-07
# Training vs. Validation Loss {'Training': 0.004721215295300378, 'Validation': 9.316483797761066e-07} 116
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 116
# Epoch 116:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0010680185264012227 valid 1.681764445653318e-07
# Training vs. Validation Loss {'Training': 0.0010680185264012227, 'Validation': 1.681764445653318e-07} 117
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 117
# Epoch 117:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005081929850803135 valid 1.1975934339940426e-07
# Training vs. Validation Loss {'Training': 0.0005081929850803135, 'Validation': 1.1975934339940426e-07} 118
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 118
# Epoch 118:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0007819589161878563 valid 8.326304411755157e-08
# Training vs. Validation Loss {'Training': 0.0007819589161878563, 'Validation': 8.326304411755157e-08} 119
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 119
# Epoch 119:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005447926077977172 valid 3.7963561388538054e-08
# Training vs. Validation Loss {'Training': 0.0005447926077977172, 'Validation': 3.7963561388538054e-08} 120
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 120
# Epoch 120:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003042270247182917 valid 5.446945773056856e-08
# Training vs. Validation Loss {'Training': 0.0003042270247182917, 'Validation': 5.446945773056856e-08} 121
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 121
# Epoch 121:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002551966571312884 valid 3.888055853342219e-08
# Training vs. Validation Loss {'Training': 0.0002551966571312884, 'Validation': 3.888055853342219e-08} 122
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 122
# Epoch 122:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0016700129521514857 valid 1.9275161934937904e-07
# Training vs. Validation Loss {'Training': 0.0016700129521514857, 'Validation': 1.9275161934937904e-07} 123
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 123
# Epoch 123:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0020883068016625352 valid 8.074987128190095e-07
# Training vs. Validation Loss {'Training': 0.0020883068016625352, 'Validation': 8.074987128190095e-07} 124
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 124
# Epoch 124:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.002919582635778776 valid 5.890711308827927e-07
# Training vs. Validation Loss {'Training': 0.002919582635778776, 'Validation': 5.890711308827927e-07} 125
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 125
# Epoch 125:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005383427491475837 valid 4.5445840622339625e-07
# Training vs. Validation Loss {'Training': 0.0005383427491475837, 'Validation': 4.5445840622339625e-07} 126
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 126
# Epoch 126:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009129970938488441 valid 5.312987416171102e-07
# Training vs. Validation Loss {'Training': 0.0009129970938488441, 'Validation': 5.312987416171102e-07} 127
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 127
# Epoch 127:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004739242548907896 valid 1.9073429850908934e-07
# Training vs. Validation Loss {'Training': 0.0004739242548907896, 'Validation': 1.9073429850908934e-07} 128
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 128
# Epoch 128:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0013757838420360713 valid 1.0783841389092267e-07
# Training vs. Validation Loss {'Training': 0.0013757838420360713, 'Validation': 1.0783841389092267e-07} 129
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 129
# Epoch 129:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0010556697619676925 valid 1.2102191829190299e-06
# Training vs. Validation Loss {'Training': 0.0010556697619676925, 'Validation': 1.2102191829190299e-06} 130
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 130
# Epoch 130:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0072343688031821785 valid 1.0112557766899063e-06
# Training vs. Validation Loss {'Training': 0.0072343688031821785, 'Validation': 1.0112557766899063e-06} 131
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 131
# Epoch 131:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.002325134596958378 valid 6.528999665697746e-08
# Training vs. Validation Loss {'Training': 0.002325134596958378, 'Validation': 6.528999665697746e-08} 132
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 132
# Epoch 132:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001167693179240814 valid 7.684412675410194e-08
# Training vs. Validation Loss {'Training': 0.001167693179240814, 'Validation': 7.684412675410194e-08} 133
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 133
# Epoch 133:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0020070703275791857 valid 2.096247400619798e-07
# Training vs. Validation Loss {'Training': 0.0020070703275791857, 'Validation': 2.096247400619798e-07} 134
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 134
# Epoch 134:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006008817117996538 valid 7.299274050144898e-08
# Training vs. Validation Loss {'Training': 0.0006008817117996538, 'Validation': 7.299274050144898e-08} 135
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 135
# Epoch 135:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0015105148823977288 valid 2.2246202654366917e-07
# Training vs. Validation Loss {'Training': 0.0015105148823977288, 'Validation': 2.2246202654366917e-07} 136
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 136
# Epoch 136:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000595020211259604 valid 1.1425742594785613e-07
# Training vs. Validation Loss {'Training': 0.000595020211259604, 'Validation': 1.1425742594785613e-07} 137
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 137
# Epoch 137:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00035772255682786636 valid 9.09657604968135e-08
# Training vs. Validation Loss {'Training': 0.00035772255682786636, 'Validation': 9.09657604968135e-08} 138
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 138
# Epoch 138:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0013250613938756335 valid 6.41896037861373e-08
# Training vs. Validation Loss {'Training': 0.0013250613938756335, 'Validation': 6.41896037861373e-08} 139
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 139
# Epoch 139:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0009085317713205162 valid 4.0916069383893745e-07
# Training vs. Validation Loss {'Training': 0.0009085317713205162, 'Validation': 4.0916069383893745e-07} 140
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 140
# Epoch 140:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007570583788189348 valid 4.9884488369127226e-08
# Training vs. Validation Loss {'Training': 0.0007570583788189348, 'Validation': 4.9884488369127226e-08} 141
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 141
# Epoch 141:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004846020075509235 valid 6.180541125043139e-08
# Training vs. Validation Loss {'Training': 0.0004846020075509235, 'Validation': 6.180541125043139e-08} 142
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 142
# Epoch 142:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00022902488660747622 valid 4.750030194818814e-08
# Training vs. Validation Loss {'Training': 0.00022902488660747622, 'Validation': 4.750030194818814e-08} 143
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 143
# Epoch 143:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005784816296075709 valid 2.8060028693761733e-08
# Training vs. Validation Loss {'Training': 0.0005784816296075709, 'Validation': 2.8060028693761733e-08} 144
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 144
# Epoch 144:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.000220504044534664 valid 1.3754915838804804e-08
# Training vs. Validation Loss {'Training': 0.000220504044534664, 'Validation': 1.3754915838804804e-08} 145
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 145
# Epoch 145:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0025527247182992596 valid 1.2819572193533392e-07
# Training vs. Validation Loss {'Training': 0.0025527247182992596, 'Validation': 1.2819572193533392e-07} 146
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 146
# Epoch 146:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0014185450503608383 valid 5.190187104029921e-08
# Training vs. Validation Loss {'Training': 0.0014185450503608383, 'Validation': 5.190187104029921e-08} 147
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 147
# Epoch 147:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004067079434169803 valid 4.750029238318977e-08
# Training vs. Validation Loss {'Training': 0.0004067079434169803, 'Validation': 4.750029238318977e-08} 148
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 148
# Epoch 148:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003500599655978931 valid 6.363939474541579e-08
# Training vs. Validation Loss {'Training': 0.0003500599655978931, 'Validation': 6.363939474541579e-08} 149
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 149
# Epoch 149:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002662123378390409 valid 4.4015726550729646e-08
# Training vs. Validation Loss {'Training': 0.0002662123378390409, 'Validation': 4.4015726550729646e-08} 150
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 150
# Epoch 150:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000982750970744443 valid 1.4726882769676965e-07
# Training vs. Validation Loss {'Training': 0.000982750970744443, 'Validation': 1.4726882769676965e-07} 151
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 151
# Epoch 151:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005126159766083068 valid 8.179583871764224e-08
# Training vs. Validation Loss {'Training': 0.0005126159766083068, 'Validation': 8.179583871764224e-08} 152
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 152
# Epoch 152:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00023966906411487798 valid 4.034775173795861e-08
# Training vs. Validation Loss {'Training': 0.00023966906411487798, 'Validation': 4.034775173795861e-08} 153
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 153
# Epoch 153:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001739635404571042 valid 4.401572316881951e-08
# Training vs. Validation Loss {'Training': 0.0001739635404571042, 'Validation': 4.401572316881951e-08} 154
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 154
# Epoch 154:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001549742508473173 valid 4.8784077495593707e-08
# Training vs. Validation Loss {'Training': 0.0001549742508473173, 'Validation': 4.8784077495593707e-08} 155
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 155
# Epoch 155:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000341637381751525 valid 3.3928780195625364e-08
# Training vs. Validation Loss {'Training': 0.000341637381751525, 'Validation': 3.3928780195625364e-08} 156
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 156
# Epoch 156:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00022213241932907599 valid 2.2374657955463835e-08
# Training vs. Validation Loss {'Training': 0.00022213241932907599, 'Validation': 2.2374657955463835e-08} 157
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 157
# Epoch 157:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001517126030989857 valid 2.4575444380358338e-08
# Training vs. Validation Loss {'Training': 0.0001517126030989857, 'Validation': 2.4575444380358338e-08} 158
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 158
# Epoch 158:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00028436576603970326 valid 2.2924852853652038e-08
# Training vs. Validation Loss {'Training': 0.00028436576603970326, 'Validation': 2.2924852853652038e-08} 159
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 159
# Epoch 159:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00018718036365328317 valid 2.879360999203256e-08
# Training vs. Validation Loss {'Training': 0.00018718036365328317, 'Validation': 2.879360999203256e-08} 160
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 160
# Epoch 160:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00017019277786782064 valid 8.252950186497051e-09
# Training vs. Validation Loss {'Training': 0.00017019277786782064, 'Validation': 8.252950186497051e-09} 161
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 161
# Epoch 161:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002862463212925566 valid 1.485530693328813e-08
# Training vs. Validation Loss {'Training': 0.0002862463212925566, 'Validation': 1.485530693328813e-08} 162
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 162
# Epoch 162:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003257607060428806 valid 1.3388116188322714e-08
# Training vs. Validation Loss {'Training': 0.0003257607060428806, 'Validation': 1.3388116188322714e-08} 163
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 163
# Epoch 163:
# Accuracy train:1.0, val:1.0
# ...
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 246
# Epoch 246:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00021582892127014475 valid 1.0453735859855966e-08
# Training vs. Validation Loss {'Training': 0.00021582892127014475, 'Validation': 1.0453735859855966e-08} 247
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 247
# Epoch 247:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0005577652028658046 valid 7.702753102023507e-09
# Training vs. Validation Loss {'Training': 0.0005577652028658046, 'Validation': 7.702753102023507e-09} 248
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 248
# Epoch 248:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012343600228964153 valid 5.3552404083872645e-08
# Training vs. Validation Loss {'Training': 0.0012343600228964153, 'Validation': 5.3552404083872645e-08} 249
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 249
# Epoch 249:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0019828078620918177 valid 3.484578916011462e-09
# Training vs. Validation Loss {'Training': 0.0019828078620918177, 'Validation': 3.484578916011462e-09} 250
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 250
# Epoch 250:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00010937700946556106 valid 3.851376721815296e-09
# Training vs. Validation Loss {'Training': 0.00010937700946556106, 'Validation': 3.851376721815296e-09} 251
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 251
# Epoch 251:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0017262693708441172 valid 4.5849721967801296e-09
# Training vs. Validation Loss {'Training': 0.0017262693708441172, 'Validation': 4.5849721967801296e-09} 252
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 252
# Epoch 252:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0024895108334064275 valid 1.5955703322681266e-08
# Training vs. Validation Loss {'Training': 0.0024895108334064275, 'Validation': 1.5955703322681266e-08} 253
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 253
# Epoch 253:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.001547280724215246 valid 6.675714640909274e-08
# Training vs. Validation Loss {'Training': 0.001547280724215246, 'Validation': 6.675714640909274e-08} 254
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 254
# Epoch 254:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0008046004051323052 valid 1.1664134765746545e-07
# Training vs. Validation Loss {'Training': 0.0008046004051323052, 'Validation': 1.1664134765746545e-07} 255
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 255
# Epoch 255:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0013002676890323528 valid 1.5167019879341453e-07
# Training vs. Validation Loss {'Training': 0.0013002676890323528, 'Validation': 1.5167019879341453e-07} 256
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 256
# Epoch 256:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011314713938948746 valid 3.759675647730686e-08
# Training vs. Validation Loss {'Training': 0.0011314713938948746, 'Validation': 3.759675647730686e-08} 257
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 257
# Epoch 257:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.0037096888378395456 valid 1.2782861599993987e-07
# Training vs. Validation Loss {'Training': 0.0037096888378395456, 'Validation': 1.2782861599993987e-07} 258
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 258
# Epoch 258:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0015142652823953995 valid 3.943075042546805e-08
# Training vs. Validation Loss {'Training': 0.0015142652823953995, 'Validation': 3.943075042546805e-08} 259
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 259
# Epoch 259:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000518537401148933 valid 1.4855308846287803e-08
# Training vs. Validation Loss {'Training': 0.000518537401148933, 'Validation': 1.4855308846287803e-08} 260
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 260
# Epoch 260:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005465591802504832 valid 5.685363892491925e-08
# Training vs. Validation Loss {'Training': 0.0005465591802504832, 'Validation': 5.685363892491925e-08} 261
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 261
# Epoch 261:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00402623079874805 valid 2.5547347915787754e-07
# Training vs. Validation Loss {'Training': 0.00402623079874805, 'Validation': 2.5547347915787754e-07} 262
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 262
# Epoch 262:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011202455679845495 valid 4.493270863074136e-08
# Training vs. Validation Loss {'Training': 0.0011202455679845495, 'Validation': 4.493270863074136e-08} 263
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 263
# Epoch 263:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003087588889854942 valid 4.951770036744672e-09
# Training vs. Validation Loss {'Training': 0.003087588889854942, 'Validation': 4.951770036744672e-09} 264
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 264
# Epoch 264:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0014353124238321395 valid 6.675709386992314e-08
# Training vs. Validation Loss {'Training': 0.0014353124238321395, 'Validation': 6.675709386992314e-08} 265
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 265
# Epoch 265:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00031297524648721264 valid 5.465282038895881e-08
# Training vs. Validation Loss {'Training': 0.00031297524648721264, 'Validation': 5.465282038895881e-08} 266
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 266
# Epoch 266:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004998568355887301 valid 4.8784081936485805e-08
# Training vs. Validation Loss {'Training': 0.0004998568355887301, 'Validation': 4.8784081936485805e-08} 267
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 267
# Epoch 267:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00015128008013221006 valid 3.7780147694049376e-08
# Training vs. Validation Loss {'Training': 0.00015128008013221006, 'Validation': 3.7780147694049376e-08} 268
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 268
# Epoch 268:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001576749151676419 valid 6.34559453871475e-08
# Training vs. Validation Loss {'Training': 0.0001576749151676419, 'Validation': 6.34559453871475e-08} 269
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 269
# Epoch 269:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00026443564118020885 valid 4.126471977791915e-08
# Training vs. Validation Loss {'Training': 0.00026443564118020885, 'Validation': 4.126471977791915e-08} 270
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 270
# Epoch 270:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0010589916955344354 valid 3.429558790803465e-08
# Training vs. Validation Loss {'Training': 0.0010589916955344354, 'Validation': 3.429558790803465e-08} 271
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 271
# Epoch 271:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00020197238654399521 valid 2.457544492692967e-08
# Training vs. Validation Loss {'Training': 0.00020197238654399521, 'Validation': 2.457544492692967e-08} 272
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 272
# Epoch 272:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002851769842209251 valid 2.255806041107943e-08
# Training vs. Validation Loss {'Training': 0.0002851769842209251, 'Validation': 2.255806041107943e-08} 273
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 273
# Epoch 273:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0006706798632052369 valid 3.172799349744519e-08
# Training vs. Validation Loss {'Training': 0.0006706798632052369, 'Validation': 3.172799349744519e-08} 274
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 274
# Epoch 274:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003433259896231296 valid 3.704656082758307e-08
# Training vs. Validation Loss {'Training': 0.0003433259896231296, 'Validation': 3.704656082758307e-08} 275
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 275
# Epoch 275:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000437443434869067 valid 3.264499252116829e-08
# Training vs. Validation Loss {'Training': 0.000437443434869067, 'Validation': 3.264499252116829e-08} 276
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 276
# Epoch 276:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.000354549076632793 valid 2.420865084464306e-08
# Training vs. Validation Loss {'Training': 0.000354549076632793, 'Validation': 2.420865084464306e-08} 277
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 277
# Epoch 277:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011927188915592524 valid 2.2558059010490385e-08
# Training vs. Validation Loss {'Training': 0.0011927188915592524, 'Validation': 2.2558059010490385e-08} 278
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 278
# Epoch 278:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003210635332777656 valid 1.6872695582584093e-08
# Training vs. Validation Loss {'Training': 0.0003210635332777656, 'Validation': 1.6872695582584093e-08} 279
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 279
# Epoch 279:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00025686969541993676 valid 8.803146075345799e-09
# Training vs. Validation Loss {'Training': 0.00025686969541993676, 'Validation': 8.803146075345799e-09} 280
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 280
# Epoch 280:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005407666826897639 valid 2.56758408722336e-08
# Training vs. Validation Loss {'Training': 0.0005407666826897639, 'Validation': 2.56758408722336e-08} 281
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 281
# Epoch 281:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0025550919523122198 valid 3.8330358716091965e-08
# Training vs. Validation Loss {'Training': 0.0025550919523122198, 'Validation': 3.8330358716091965e-08} 282
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 282
# Epoch 282:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00046462362257670975 valid 6.400616095256431e-08
# Training vs. Validation Loss {'Training': 0.00046462362257670975, 'Validation': 6.400616095256431e-08} 283
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 283
# Epoch 283:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00024389890092872216 valid 4.0897936558737825e-08
# Training vs. Validation Loss {'Training': 0.00024389890092872216, 'Validation': 4.0897936558737825e-08} 284
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 284
# Epoch 284:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000313161220465948 valid 2.1274261600231405e-08
# Training vs. Validation Loss {'Training': 0.000313161220465948, 'Validation': 2.1274261600231405e-08} 285
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 285
# Epoch 285:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00022914689641595487 valid 2.5859236973957422e-08
# Training vs. Validation Loss {'Training': 0.00022914689641595487, 'Validation': 2.5859236973957422e-08} 286
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 286
# Epoch 286:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0019557691587550607 valid 9.169944871810177e-09
# Training vs. Validation Loss {'Training': 0.0019557691587550607, 'Validation': 9.169944871810177e-09} 287
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 287
# Epoch 287:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0027286562609134535 valid 3.0994397202623354e-08
# Training vs. Validation Loss {'Training': 0.0027286562609134535, 'Validation': 3.0994397202623354e-08} 288
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 288
# Epoch 288:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0013638577552512743 valid 8.729765382370785e-08
# Training vs. Validation Loss {'Training': 0.0013638577552512743, 'Validation': 8.729765382370785e-08} 289
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 289
# Epoch 289:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.001988727998337936 valid 1.384657755975328e-07
# Training vs. Validation Loss {'Training': 0.001988727998337936, 'Validation': 1.384657755975328e-07} 290
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 290
# Epoch 290:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0015565146014182574 valid 5.336901559998681e-08
# Training vs. Validation Loss {'Training': 0.0015565146014182574, 'Validation': 5.336901559998681e-08} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 291
# Epoch 291:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005680929936969411 valid 1.302131749434046e-08
# Training vs. Validation Loss {'Training': 0.0005680929936969411, 'Validation': 1.302131749434046e-08} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 292
# Epoch 292:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016512718513439495 valid 1.8890076374917115e-08
# Training vs. Validation Loss {'Training': 0.00016512718513439495, 'Validation': 1.8890076374917115e-08} 293
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 293
# Epoch 293:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00019443063176301698 valid 1.5038701771065742e-08
# Training vs. Validation Loss {'Training': 0.00019443063176301698, 'Validation': 1.5038701771065742e-08} 294
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 294
# Epoch 294:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016258676793275603 valid 1.0637131824936956e-08
# Training vs. Validation Loss {'Training': 0.00016258676793275603, 'Validation': 1.0637131824936956e-08} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 295
# Epoch 295:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001091282143724707 valid 3.301178646681207e-08
# Training vs. Validation Loss {'Training': 0.001091282143724707, 'Validation': 3.301178646681207e-08} 296
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 296
# Epoch 296:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0006309939168787082 valid 2.6592821278370593e-08
# Training vs. Validation Loss {'Training': 0.0006309939168787082, 'Validation': 2.6592821278370593e-08} 297
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 297
# Epoch 297:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000163051345812922 valid 1.7973086779549547e-08
# Training vs. Validation Loss {'Training': 0.000163051345812922, 'Validation': 1.7973086779549547e-08} 298
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 298
# Epoch 298:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003099331673958261 valid 4.4199074759140224e-08
# Training vs. Validation Loss {'Training': 0.003099331673958261, 'Validation': 4.4199074759140224e-08} 299
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 299
# Epoch 299:
# Accuracy train:1.0, val:1.0
# LOSS train 6.987771025990241e-05 valid 2.017387228210492e-08
# Training vs. Validation Loss {'Training': 6.987771025990241e-05, 'Validation': 2.017387228210492e-08} 300
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 300
# tensor(1.)

# %%
list_label = label_dict_from_config_file("../hand_gesture.yaml")
DATA_FOLDER_PATH="../data_collection/data2/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    
    preds = network(test_input)
    acc_test.update(preds, test_label)

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:1.0
# ========================================================================

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("../hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label))
        )
        
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob, dim=1)
        return torch.where(softmax_prob[0,chosen_ind] > threshold,chosen_ind,-1)

    def predict_with_known_class(self, x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob, dim=1)

    def score(self,logits):
        return -torch.amax(logits, dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path, "r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False, max_num_hands=1, min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x, landmark.y, landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H_%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number, data in enumerate(trainloader):
            inputs,labels = data

            # reset gradients, dự đoán class cử chỉ của inputs
            optimizer.zero_grad()
            preds = model(inputs)
            
            # tính loss, backward và update parameters
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="../data_collection/data2/"
LIST_LABEL = label_dict_from_config_file("../hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH, "landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH, "landmark_val.csv")
save_path = '.'
os.makedirs(save_path, exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True, drop_last=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset, batch_size=50, shuffle=False, drop_last=True)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.29479166865348816, val:0.7200000286102295
# LOSS train 1.5927266503373783 valid 1.558190868451045
# Training vs. Validation Loss {'Training': 1.5927266503373783, 'Validation': 1.558190868451045} 1
# Training vs. Validation accuracy {'Training': 0.29479166865348816, 'Validation': 0.7200000286102295} 1
# Epoch 1:
# Accuracy train:0.4833333194255829, val:0.7676923274993896
# LOSS train 1.528943898777167 valid 1.4601109944857085
# Training vs. Validation Loss {'Training': 1.528943898777167, 'Validation': 1.4601109944857085} 2
# Training vs. Validation accuracy {'Training': 0.4833333194255829, 'Validation': 0.7676923274993896} 2
# Epoch 2:
# Accuracy train:0.6442708373069763, val:0.8215384483337402
# LOSS train 1.3763937478264172 valid 1.193449501807873
# Training vs. Validation Loss {'Training': 1.3763937478264172, 'Validation': 1.193449501807873} 3
# Training vs. Validation accuracy {'Training': 0.6442708373069763, 'Validation': 0.8215384483337402} 3
# Epoch 3:
# Accuracy train:0.746874988079071, val:0.9630769491195679
# LOSS train 1.053038979570071 valid 0.7270249540989215
# Training vs. Validation Loss {'Training': 1.053038979570071, 'Validation': 0.7270249540989215} 4
# Training vs. Validation accuracy {'Training': 0.746874988079071, 'Validation': 0.9630769491195679} 4
# Epoch 4:
# Accuracy train:0.8786458373069763, val:1.0
# LOSS train 0.6603727744271358 valid 0.31699997702470195
# Training vs. Validation Loss {'Training': 0.6603727744271358, 'Validation': 0.31699997702470195} 5
# Training vs. Validation accuracy {'Training': 0.8786458373069763, 'Validation': 1.0} 5
# Epoch 5:
# Accuracy train:0.9546874761581421, val:1.0
# LOSS train 0.3602405348792672 valid 0.08991692856384012
# Training vs. Validation Loss {'Training': 0.3602405348792672, 'Validation': 0.08991692856384012} 6
# Training vs. Validation accuracy {'Training': 0.9546874761581421, 'Validation': 1.0} 6
# Epoch 6:
# Accuracy train:0.987500011920929, val:1.0
# LOSS train 0.17732877936214209 valid 0.021386033246436946
# Training vs. Validation Loss {'Training': 0.17732877936214209, 'Validation': 0.021386033246436946} 7
# Training vs. Validation accuracy {'Training': 0.987500011920929, 'Validation': 1.0} 7
# Epoch 7:
# Accuracy train:0.9895833134651184, val:1.0
# LOSS train 0.09571082835706572 valid 0.0074363111769064115
# Training vs. Validation Loss {'Training': 0.09571082835706572, 'Validation': 0.0074363111769064115} 8
# Training vs. Validation accuracy {'Training': 0.9895833134651184, 'Validation': 1.0} 8
# Epoch 8:
# Accuracy train:0.995312511920929, val:1.0
# LOSS train 0.06388423518122484 valid 0.0027965370592517923
# Training vs. Validation Loss {'Training': 0.06388423518122484, 'Validation': 0.0027965370592517923} 9
# Training vs. Validation accuracy {'Training': 0.995312511920929, 'Validation': 1.0} 9
# Epoch 9:
# Accuracy train:0.995312511920929, val:1.0
# LOSS train 0.04489168932195753 valid 0.0014760616736916395
# Training vs. Validation Loss {'Training': 0.04489168932195753, 'Validation': 0.0014760616736916395} 10
# Training vs. Validation accuracy {'Training': 0.995312511920929, 'Validation': 1.0} 10
# Epoch 10:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.032936039147898555 valid 0.0008385292452518255
# Training vs. Validation Loss {'Training': 0.032936039147898555, 'Validation': 0.0008385292452518255} 11
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 11
# Epoch 11:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.025642000943965588 valid 0.00048549677460239484
# Training vs. Validation Loss {'Training': 0.025642000943965588, 'Validation': 0.00048549677460239484} 12
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 12
# Epoch 12:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.021850590652320534 valid 0.0003333402128191665
# Training vs. Validation Loss {'Training': 0.021850590652320534, 'Validation': 0.0003333402128191665} 13
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 13
# Epoch 13:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.01650621222506743 valid 0.00020677576517650427
# Training vs. Validation Loss {'Training': 0.01650621222506743, 'Validation': 0.00020677576517650427} 14
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 14
# Epoch 14:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.015039265189746706 valid 0.00011338330393930216
# Training vs. Validation Loss {'Training': 0.015039265189746706, 'Validation': 0.00011338330393930216} 15
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 15
# Epoch 15:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.016953517915681005 valid 9.661243599951446e-05
# Training vs. Validation Loss {'Training': 0.016953517915681005, 'Validation': 9.661243599951446e-05} 16
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 16
# Epoch 16:
# Accuracy train:0.996874988079071, val:1.0
# LOSS train 0.01888338238010571 valid 0.00010332164730733403
# Training vs. Validation Loss {'Training': 0.01888338238010571, 'Validation': 0.00010332164730733403} 17
# Training vs. Validation accuracy {'Training': 0.996874988079071, 'Validation': 1.0} 17
# Epoch 17:
# Accuracy train:0.9973958134651184, val:1.0
# LOSS train 0.010840198869118467 valid 7.897827813744348e-05
# Training vs. Validation Loss {'Training': 0.010840198869118467, 'Validation': 7.897827813744348e-05} 18
# Training vs. Validation accuracy {'Training': 0.9973958134651184, 'Validation': 1.0} 18
# Epoch 18:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.011065421659926264 valid 6.000339383787762e-05
# Training vs. Validation Loss {'Training': 0.011065421659926264, 'Validation': 6.000339383787762e-05} 19
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 19
# Epoch 19:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.01112676566602507 valid 3.4421887448843336e-05
# Training vs. Validation Loss {'Training': 0.01112676566602507, 'Validation': 3.4421887448843336e-05} 20
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 20
# Epoch 20:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.010319578260047516 valid 2.8137247279748688e-05
# Training vs. Validation Loss {'Training': 0.010319578260047516, 'Validation': 2.8137247279748688e-05} 21
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 21
# Epoch 21:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.011383989246193474 valid 2.51922687521773e-05
# Training vs. Validation Loss {'Training': 0.011383989246193474, 'Validation': 2.51922687521773e-05} 22
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 22
# Epoch 22:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.010236623978319889 valid 2.68552870028753e-05
# Training vs. Validation Loss {'Training': 0.010236623978319889, 'Validation': 2.68552870028753e-05} 23
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 23
# Epoch 23:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.008487575835412523 valid 1.8273473957518807e-05
# Training vs. Validation Loss {'Training': 0.008487575835412523, 'Validation': 1.8273473957518807e-05} 24
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 24
# Epoch 24:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.012744221685958715 valid 1.7197284198398567e-05
# Training vs. Validation Loss {'Training': 0.012744221685958715, 'Validation': 1.7197284198398567e-05} 25
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 25
# Epoch 25:
# Accuracy train:1.0, val:1.0
# LOSS train 0.006873857370616558 valid 1.2488519757880567e-05
# Training vs. Validation Loss {'Training': 0.006873857370616558, 'Validation': 1.2488519757880567e-05} 26
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 26
# Epoch 26:
# Accuracy train:0.9984375238418579, val:1.0
# LOSS train 0.008058217224364247 valid 2.939853968305565e-05
# Training vs. Validation Loss {'Training': 0.008058217224364247, 'Validation': 2.939853968305565e-05} 27
# Training vs. Validation accuracy {'Training': 0.9984375238418579, 'Validation': 1.0} 27
# Epoch 27:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00758144411520334 valid 1.45337606647025e-05
# Training vs. Validation Loss {'Training': 0.00758144411520334, 'Validation': 1.45337606647025e-05} 28
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 28
# Epoch 28:
# Accuracy train:1.0, val:1.0
# LOSS train 0.006173293567068565 valid 8.66090450612179e-06
# Training vs. Validation Loss {'Training': 0.006173293567068565, 'Validation': 8.66090450612179e-06} 29
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 29
# Epoch 29:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.007187661919791329 valid 8.776277625726765e-06
# Training vs. Validation Loss {'Training': 0.007187661919791329, 'Validation': 8.776277625726765e-06} 30
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 30
# Epoch 30:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0059228756169128855 valid 9.234934168489417e-06
# Training vs. Validation Loss {'Training': 0.0059228756169128855, 'Validation': 9.234934168489417e-06} 31
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 31
# Epoch 31:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0038361331450384264 valid 5.914751813389347e-06
# Training vs. Validation Loss {'Training': 0.0038361331450384264, 'Validation': 5.914751813389347e-06} 32
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 32
# Epoch 32:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.004479643951223504 valid 1.0791049186528093e-05
# Training vs. Validation Loss {'Training': 0.004479643951223504, 'Validation': 1.0791049186528093e-05} 33
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 33
# Epoch 33:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0028235438827929706 valid 4.258313310856465e-06
# Training vs. Validation Loss {'Training': 0.0028235438827929706, 'Validation': 4.258313310856465e-06} 34
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 34
# Epoch 34:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0033338311932311626 valid 2.6400186225845782e-06
# Training vs. Validation Loss {'Training': 0.0033338311932311626, 'Validation': 2.6400186225845782e-06} 35
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 35
# Epoch 35:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00464276502316352 valid 2.356299553696317e-06
# Training vs. Validation Loss {'Training': 0.00464276502316352, 'Validation': 2.356299553696317e-06} 36
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 36
# Epoch 36:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00404066023111227 valid 2.298714981372121e-06
# Training vs. Validation Loss {'Training': 0.00404066023111227, 'Validation': 2.298714981372121e-06} 37
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 37
# Epoch 37:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.002941414826940066 valid 3.1489461754028107e-06
# Training vs. Validation Loss {'Training': 0.002941414826940066, 'Validation': 3.1489461754028107e-06} 38
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 38
# Epoch 38:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003109033968333582 valid 2.2004118442544914e-06
# Training vs. Validation Loss {'Training': 0.003109033968333582, 'Validation': 2.2004118442544914e-06} 39
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 39
# Epoch 39:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.008621338859787405 valid 2.136591934214056e-06
# Training vs. Validation Loss {'Training': 0.008621338859787405, 'Validation': 2.136591934214056e-06} 40
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 40
# Epoch 40:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001797638033167459 valid 1.3281725864763198e-06
# Training vs. Validation Loss {'Training': 0.001797638033167459, 'Validation': 1.3281725864763198e-06} 41
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 41
# Epoch 41:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0018310645070111302 valid 1.2318887500511594e-06
# Training vs. Validation Loss {'Training': 0.0018310645070111302, 'Validation': 1.2318887500511594e-06} 42
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 42
# Epoch 42:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0039677327543662004 valid 1.237757818837683e-06
# Training vs. Validation Loss {'Training': 0.0039677327543662004, 'Validation': 1.237757818837683e-06} 43
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 43
# Epoch 43:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0030649139262853473 valid 1.3921787692917376e-06
# Training vs. Validation Loss {'Training': 0.0030649139262853473, 'Validation': 1.3921787692917376e-06} 44
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.003095477593584898 valid 8.260280205481999e-07
# Training vs. Validation Loss {'Training': 0.003095477593584898, 'Validation': 8.260280205481999e-07} 45
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 45
# Epoch 45:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.002738455520405599 valid 2.0289292253804747e-06
# Training vs. Validation Loss {'Training': 0.002738455520405599, 'Validation': 2.0289292253804747e-06} 46
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 46
# Epoch 46:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0023129623800741683 valid 6.52165796238408e-07
# Training vs. Validation Loss {'Training': 0.0023129623800741683, 'Validation': 6.52165796238408e-07} 47
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 47
# Epoch 47:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003294278248934764 valid 8.766455311414435e-07
# Training vs. Validation Loss {'Training': 0.003294278248934764, 'Validation': 8.766455311414435e-07} 48
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 48
# Epoch 48:
# Accuracy train:1.0, val:1.0
# LOSS train 0.003595406633545887 valid 8.296949274630641e-07
# Training vs. Validation Loss {'Training': 0.003595406633545887, 'Validation': 8.296949274630641e-07} 49
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 49
# Epoch 49:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001698520675366429 valid 4.5776344301465053e-07
# Training vs. Validation Loss {'Training': 0.001698520675366429, 'Validation': 4.5776344301465053e-07} 50
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 50
# Epoch 50:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004831476768231369 valid 9.085561376746927e-07
# Training vs. Validation Loss {'Training': 0.004831476768231369, 'Validation': 9.085561376746927e-07} 51
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 51
# Epoch 51:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017651028295707267 valid 3.756007933393317e-07
# Training vs. Validation Loss {'Training': 0.0017651028295707267, 'Validation': 3.756007933393317e-07} 52
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 52
# Epoch 52:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017823063550016134 valid 6.606017799107086e-07
# Training vs. Validation Loss {'Training': 0.0017823063550016134, 'Validation': 6.606017799107086e-07} 53
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 53
# Epoch 53:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0027327140769557445 valid 1.0099753169175056e-06
# Training vs. Validation Loss {'Training': 0.0027327140769557445, 'Validation': 1.0099753169175056e-06} 54
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 54
# Epoch 54:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0019374779938819604 valid 7.453317261152392e-07
# Training vs. Validation Loss {'Training': 0.0019374779938819604, 'Validation': 7.453317261152392e-07} 55
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 55
# Epoch 55:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0018877763380563313 valid 3.6863157886885415e-07
# Training vs. Validation Loss {'Training': 0.0018877763380563313, 'Validation': 3.6863157886885415e-07} 56
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 56
# Epoch 56:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009798942487577733 valid 3.033416581169709e-07
# Training vs. Validation Loss {'Training': 0.0009798942487577733, 'Validation': 3.033416581169709e-07} 57
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 57
# Epoch 57:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0032024915360580053 valid 9.669960983416104e-05
# Training vs. Validation Loss {'Training': 0.0032024915360580053, 'Validation': 9.669960983416104e-05} 58
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 58
# Epoch 58:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004447826458620814 valid 1.2843402496051008e-06
# Training vs. Validation Loss {'Training': 0.004447826458620814, 'Validation': 1.2843402496051008e-06} 59
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 59
# Epoch 59:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0045885909809536924 valid 1.4976322300587806e-06
# Training vs. Validation Loss {'Training': 0.0045885909809536924, 'Validation': 1.4976322300587806e-06} 60
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 60
# Epoch 60:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.001290539304439638 valid 1.0019066432566713e-06
# Training vs. Validation Loss {'Training': 0.001290539304439638, 'Validation': 1.0019066432566713e-06} 61
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 61
# Epoch 61:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002501658320701002 valid 7.218573100632196e-07
# Training vs. Validation Loss {'Training': 0.002501658320701002, 'Validation': 7.218573100632196e-07} 62
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 62
# Epoch 62:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0017117141017782462 valid 9.008540593833039e-07
# Training vs. Validation Loss {'Training': 0.0017117141017782462, 'Validation': 9.008540593833039e-07} 63
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 63
# Epoch 63:
# Accuracy train:1.0, val:1.0
# LOSS train 0.008854569942741364 valid 2.235243659225279e-06
# Training vs. Validation Loss {'Training': 0.008854569942741364, 'Validation': 2.235243659225279e-06} 64
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 64
# Epoch 64:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.003116768598829367 valid 8.751777701176112e-07
# Training vs. Validation Loss {'Training': 0.003116768598829367, 'Validation': 8.751777701176112e-07} 65
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 65
# Epoch 65:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004172301599889276 valid 9.725626975218495e-07
# Training vs. Validation Loss {'Training': 0.004172301599889276, 'Validation': 9.725626975218495e-07} 66
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 66
# Epoch 66:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004260400147510761 valid 9.446846505056783e-07
# Training vs. Validation Loss {'Training': 0.004260400147510761, 'Validation': 9.446846505056783e-07} 67
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 67
# Epoch 67:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0014755290088335944 valid 7.132368530995756e-07
# Training vs. Validation Loss {'Training': 0.0014755290088335944, 'Validation': 7.132368530995756e-07} 68
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 68
# Epoch 68:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0027781106862979263 valid 6.343751654578857e-07
# Training vs. Validation Loss {'Training': 0.0027781106862979263, 'Validation': 6.343751654578857e-07} 69
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 69
# Epoch 69:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0034715985101077726 valid 1.258654530344162e-06
# Training vs. Validation Loss {'Training': 0.0034715985101077726, 'Validation': 1.258654530344162e-06} 70
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 70
# Epoch 70:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0013574286795877317 valid 5.41208987232704e-07
# Training vs. Validation Loss {'Training': 0.0013574286795877317, 'Validation': 5.41208987232704e-07} 71
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 71
# Epoch 71:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.004445610574805414 valid 7.114022395444846e-07
# Training vs. Validation Loss {'Training': 0.004445610574805414, 'Validation': 7.114022395444846e-07} 72
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 72
# Epoch 72:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0022060334546646723 valid 1.2349957446102276e-06
# Training vs. Validation Loss {'Training': 0.0022060334546646723, 'Validation': 1.2349957446102276e-06} 73
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 73
# Epoch 73:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017543482351053778 valid 4.982936666363659e-07
# Training vs. Validation Loss {'Training': 0.0017543482351053778, 'Validation': 4.982936666363659e-07} 74
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 74
# Epoch 74:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0008741767110223009 valid 3.081097055439404e-07
# Training vs. Validation Loss {'Training': 0.0008741767110223009, 'Validation': 3.081097055439404e-07} 75
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 75
# Epoch 75:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0008041043594554745 valid 1.7257827201488087e-07
# Training vs. Validation Loss {'Training': 0.0008041043594554745, 'Validation': 1.7257827201488087e-07} 76
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 76
# Epoch 76:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012376307175069694 valid 2.591424609258516e-07
# Training vs. Validation Loss {'Training': 0.0012376307175069694, 'Validation': 2.591424609258516e-07} 77
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 77
# Epoch 77:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000579112451760011 valid 1.6505895870612727e-07
# Training vs. Validation Loss {'Training': 0.000579112451760011, 'Validation': 1.6505895870612727e-07} 78
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 78
# Epoch 78:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009742280743315254 valid 9.995235678444531e-08
# Training vs. Validation Loss {'Training': 0.0009742280743315254, 'Validation': 9.995235678444531e-08} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 79
# Epoch 79:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006449653470781413 valid 8.34464802556257e-08
# Training vs. Validation Loss {'Training': 0.0006449653470781413, 'Validation': 8.34464802556257e-08} 80
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 80
# Epoch 80:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0013357433260428782 valid 1.3571509700664836e-07
# Training vs. Validation Loss {'Training': 0.0013357433260428782, 'Validation': 1.3571509700664836e-07} 81
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 81
# Epoch 81:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0019967598192730898 valid 1.2846798507728006e-06
# Training vs. Validation Loss {'Training': 0.0019967598192730898, 'Validation': 1.2846798507728006e-06} 82
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 82
# Epoch 82:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00119904182057932 valid 1.5148737932444936e-07
# Training vs. Validation Loss {'Training': 0.00119904182057932, 'Validation': 1.5148737932444936e-07} 83
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 83
# Epoch 83:
# Accuracy train:1.0, val:1.0
# LOSS train 0.004604653519209023 valid 1.4292016293173158e-06
# Training vs. Validation Loss {'Training': 0.004604653519209023, 'Validation': 1.4292016293173158e-06} 84
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 84
# Epoch 84:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.000799655663665059 valid 5.025099490023439e-07
# Training vs. Validation Loss {'Training': 0.000799655663665059, 'Validation': 5.025099490023439e-07} 85
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 85
# Epoch 85:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007415489939148756 valid 2.2668052190866206e-07
# Training vs. Validation Loss {'Training': 0.0007415489939148756, 'Validation': 2.2668052190866206e-07} 86
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 86
# Epoch 86:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006812974611420941 valid 1.9605302478900364e-07
# Training vs. Validation Loss {'Training': 0.0006812974611420941, 'Validation': 1.9605302478900364e-07} 87
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 87
# Epoch 87:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002720604841859616 valid 2.402520453350995e-07
# Training vs. Validation Loss {'Training': 0.002720604841859616, 'Validation': 2.402520453350995e-07} 88
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 88
# Epoch 88:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0010868391736570022 valid 2.4557062694441356e-07
# Training vs. Validation Loss {'Training': 0.0010868391736570022, 'Validation': 2.4557062694441356e-07} 89
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 89
# Epoch 89:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005926797237331508 valid 1.379158779658295e-07
# Training vs. Validation Loss {'Training': 0.0005926797237331508, 'Validation': 1.379158779658295e-07} 90
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 90
# Epoch 90:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007596336273157552 valid 1.1719182933480108e-07
# Training vs. Validation Loss {'Training': 0.0007596336273157552, 'Validation': 1.1719182933480108e-07} 91
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 91
# Epoch 91:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001532550776971675 valid 4.7843790812206725e-06
# Training vs. Validation Loss {'Training': 0.001532550776971675, 'Validation': 4.7843790812206725e-06} 92
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 92
# Epoch 92:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011110059727267678 valid 1.2177674748934044e-07
# Training vs. Validation Loss {'Training': 0.0011110059727267678, 'Validation': 1.2177674748934044e-07} 93
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 93
# Epoch 93:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007518454781632045 valid 7.134213807747668e-08
# Training vs. Validation Loss {'Training': 0.0007518454781632045, 'Validation': 7.134213807747668e-08} 94
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 94
# Epoch 94:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006825603852954979 valid 7.152553120721888e-08
# Training vs. Validation Loss {'Training': 0.0006825603852954979, 'Validation': 7.152553120721888e-08} 95
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 95
# Epoch 95:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004356480311192475 valid 7.06085290748713e-08
# Training vs. Validation Loss {'Training': 0.0004356480311192475, 'Validation': 7.06085290748713e-08} 96
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 96
# Epoch 96:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00045505312001144677 valid 1.0728828779240128e-07
# Training vs. Validation Loss {'Training': 0.00045505312001144677, 'Validation': 1.0728828779240128e-07} 97
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 97
# Epoch 97:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004021407073461584 valid 5.116827317408479e-08
# Training vs. Validation Loss {'Training': 0.0004021407073461584, 'Validation': 5.116827317408479e-08} 98
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 98
# Epoch 98:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00025738198719219935 valid 1.0160290407303417e-07
# Training vs. Validation Loss {'Training': 0.00025738198719219935, 'Validation': 1.0160290407303417e-07} 99
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 99
# Epoch 99:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006848124015069365 valid 2.879362369047665e-08
# Training vs. Validation Loss {'Training': 0.0006848124015069365, 'Validation': 2.879362369047665e-08} 100
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 100
# Epoch 100:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002327180806105389 valid 5.446944966864136e-08
# Training vs. Validation Loss {'Training': 0.0002327180806105389, 'Validation': 5.446944966864136e-08} 101
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 101
# Epoch 101:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002535291940072663 valid 4.4382525415515445e-08
# Training vs. Validation Loss {'Training': 0.0002535291940072663, 'Validation': 4.4382525415515445e-08} 102
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 102
# Epoch 102:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00032846898438757915 valid 3.026081081440697e-08
# Training vs. Validation Loss {'Training': 0.00032846898438757915, 'Validation': 3.026081081440697e-08} 103
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 103
# Epoch 103:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00036549626433194743 valid 1.3204718686009842e-08
# Training vs. Validation Loss {'Training': 0.00036549626433194743, 'Validation': 1.3204718686009842e-08} 104
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 104
# Epoch 104:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011127994307760976 valid 2.3346561443068262e-07
# Training vs. Validation Loss {'Training': 0.0011127994307760976, 'Validation': 2.3346561443068262e-07} 105
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 105
# Epoch 105:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0015338795977489401 valid 6.27224070972086e-08
# Training vs. Validation Loss {'Training': 0.0015338795977489401, 'Validation': 6.27224070972086e-08} 106
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 106
# Epoch 106:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.003002913152158726 valid 1.4598524331268857e-07
# Training vs. Validation Loss {'Training': 0.003002913152158726, 'Validation': 1.4598524331268857e-07} 107
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 107
# Epoch 107:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0007210904399433579 valid 1.4836945197224884e-07
# Training vs. Validation Loss {'Training': 0.0007210904399433579, 'Validation': 1.4836945197224884e-07} 108
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 108
# Epoch 108:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0006175627178208742 valid 3.007740832463067e-08
# Training vs. Validation Loss {'Training': 0.0006175627178208742, 'Validation': 3.007740832463067e-08} 109
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 109
# Epoch 109:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0027208307981633575 valid 2.2007861686891882e-08
# Training vs. Validation Loss {'Training': 0.0027208307981633575, 'Validation': 2.2007861686891882e-08} 110
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 110
# Epoch 110:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.004031909308196191 valid 9.169944393560259e-09
# Training vs. Validation Loss {'Training': 0.004031909308196191, 'Validation': 9.169944393560259e-09} 111
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 111
# Epoch 111:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.005903038654404706 valid 3.8880551052227034e-08
# Training vs. Validation Loss {'Training': 0.005903038654404706, 'Validation': 3.8880551052227034e-08} 112
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 112
# Epoch 112:
# Accuracy train:0.9989583492279053, val:1.0
# LOSS train 0.0015996173270120078 valid 2.7693228325904766e-08
# Training vs. Validation Loss {'Training': 0.0015996173270120078, 'Validation': 2.7693228325904766e-08} 113
# Training vs. Validation accuracy {'Training': 0.9989583492279053, 'Validation': 1.0} 113
# Epoch 113:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.000625689165606976 valid 9.445029637033232e-08
# Training vs. Validation Loss {'Training': 0.000625689165606976, 'Validation': 9.445029637033232e-08} 114
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 114
# Epoch 114:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007295790661980087 valid 9.70179066656512e-08
# Training vs. Validation Loss {'Training': 0.0007295790661980087, 'Validation': 9.70179066656512e-08} 115
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 115
# Epoch 115:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007940072657580307 valid 1.2617799181559627e-07
# Training vs. Validation Loss {'Training': 0.0007940072657580307, 'Validation': 1.2617799181559627e-07} 116
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 116
# Epoch 116:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005194543429070109 valid 9.16993384473349e-08
# Training vs. Validation Loss {'Training': 0.0005194543429070109, 'Validation': 9.16993384473349e-08} 117
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 117
# Epoch 117:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005140632299192779 valid 3.0260805212050784e-08
# Training vs. Validation Loss {'Training': 0.0005140632299192779, 'Validation': 3.0260805212050784e-08} 118
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 118
# Epoch 118:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00021855255206067645 valid 1.1370729827794216e-08
# Training vs. Validation Loss {'Training': 0.00021855255206067645, 'Validation': 1.1370729827794216e-08} 119
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 119
# Epoch 119:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004023506819332094 valid 1.9256878689934464e-08
# Training vs. Validation Loss {'Training': 0.0004023506819332094, 'Validation': 1.9256878689934464e-08} 120
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 120
# Epoch 120:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004639053303350238 valid 5.5569799292024633e-08
# Training vs. Validation Loss {'Training': 0.0004639053303350238, 'Validation': 5.5569799292024633e-08} 121
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 121
# Epoch 121:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00037616277219854055 valid 2.1641062343856167e-08
# Training vs. Validation Loss {'Training': 0.00037616277219854055, 'Validation': 2.1641062343856167e-08} 122
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 122
# Epoch 122:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00030791918680013924 valid 1.907347790819358e-08
# Training vs. Validation Loss {'Training': 0.00030791918680013924, 'Validation': 1.907347790819358e-08} 123
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 123
# Epoch 123:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.00018785218617267674 valid 2.2558057814865588e-08
# Training vs. Validation Loss {'Training': 0.00018785218617267674, 'Validation': 2.2558057814865588e-08} 124
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 124
# Epoch 124:
# Accuracy train:1.0, val:1.0
# LOSS train 0.005962922240001944 valid 1.4016054656041688e-06
# Training vs. Validation Loss {'Training': 0.005962922240001944, 'Validation': 1.4016054656041688e-06} 125
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 125
# Epoch 125:
# Accuracy train:0.9979166388511658, val:1.0
# LOSS train 0.01981137083707078 valid 3.5853784594244496e-07
# Training vs. Validation Loss {'Training': 0.01981137083707078, 'Validation': 3.5853784594244496e-07} 126
# Training vs. Validation accuracy {'Training': 0.9979166388511658, 'Validation': 1.0} 126
# Epoch 126:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007326484648425927 valid 1.5185410426546207e-07
# Training vs. Validation Loss {'Training': 0.0007326484648425927, 'Validation': 1.5185410426546207e-07} 127
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 127
# Epoch 127:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0010516371154380977 valid 1.536876129607597e-07
# Training vs. Validation Loss {'Training': 0.0010516371154380977, 'Validation': 1.536876129607597e-07} 128
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 128
# Epoch 128:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004528320606596026 valid 1.0417049267630318e-07
# Training vs. Validation Loss {'Training': 0.0004528320606596026, 'Validation': 1.0417049267630318e-07} 129
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 129
# Epoch 129:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005648479609211184 valid 5.777061810127074e-08
# Training vs. Validation Loss {'Training': 0.0005648479609211184, 'Validation': 5.777061810127074e-08} 130
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 130
# Epoch 130:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0018916137432446096 valid 3.979734132669294e-07
# Training vs. Validation Loss {'Training': 0.0018916137432446096, 'Validation': 3.979734132669294e-07} 131
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 131
# Epoch 131:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000759557410352348 valid 3.282839603576585e-08
# Training vs. Validation Loss {'Training': 0.000759557410352348, 'Validation': 3.282839603576585e-08} 132
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 132
# Epoch 132:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004595656902210976 valid 2.8426826772851236e-08
# Training vs. Validation Loss {'Training': 0.0004595656902210976, 'Validation': 2.8426826772851236e-08} 133
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 133
# Epoch 133:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007707963346585226 valid 3.0444205515541746e-08
# Training vs. Validation Loss {'Training': 0.0007707963346585226, 'Validation': 3.0444205515541746e-08} 134
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 134
# Epoch 134:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00019762124480848797 valid 2.365845283783039e-08
# Training vs. Validation Loss {'Training': 0.00019762124480848797, 'Validation': 2.365845283783039e-08} 135
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 135
# Epoch 135:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00038360543076502535 valid 2.0357266641632613e-08
# Training vs. Validation Loss {'Training': 0.00038360543076502535, 'Validation': 2.0357266641632613e-08} 136
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 136
# Epoch 136:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0005155771498361142 valid 3.4112155630120576e-08
# Training vs. Validation Loss {'Training': 0.0005155771498361142, 'Validation': 3.4112155630120576e-08} 137
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 137
# Epoch 137:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00026795242626083865 valid 2.8243413146683977e-08
# Training vs. Validation Loss {'Training': 0.00026795242626083865, 'Validation': 2.8243413146683977e-08} 138
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 138
# Epoch 138:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0011087939554101922 valid 2.237465187485773e-08
# Training vs. Validation Loss {'Training': 0.0011087939554101922, 'Validation': 2.237465187485773e-08} 139
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 139
# Epoch 139:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003024969791833125 valid 2.5492443233277893e-08
# Training vs. Validation Loss {'Training': 0.0003024969791833125, 'Validation': 2.5492443233277893e-08} 140
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 140
# Epoch 140:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0008198456904816945 valid 1.5112044484165102e-07
# Training vs. Validation Loss {'Training': 0.0008198456904816945, 'Validation': 1.5112044484165102e-07} 141
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 141
# Epoch 141:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000518946946054181 valid 6.749064230559244e-08
# Training vs. Validation Loss {'Training': 0.000518946946054181, 'Validation': 6.749064230559244e-08} 142
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 142
# Epoch 142:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004607026454076883 valid 4.5116053115634713e-08
# Training vs. Validation Loss {'Training': 0.0004607026454076883, 'Validation': 4.5116053115634713e-08} 143
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 143
# Epoch 143:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00036788352515297146 valid 6.088825006582528e-08
# Training vs. Validation Loss {'Training': 0.00036788352515297146, 'Validation': 6.088825006582528e-08} 144
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 144
# Epoch 144:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001340004693171674 valid 9.628429725311732e-08
# Training vs. Validation Loss {'Training': 0.001340004693171674, 'Validation': 9.628429725311732e-08} 145
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 145
# Epoch 145:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0022678723981168027 valid 1.3938314878349555e-08
# Training vs. Validation Loss {'Training': 0.0022678723981168027, 'Validation': 1.3938314878349555e-08} 146
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 146
# Epoch 146:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00139511314214739 valid 1.8119766466749246e-07
# Training vs. Validation Loss {'Training': 0.00139511314214739, 'Validation': 1.8119766466749246e-07} 147
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 147
# Epoch 147:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0012049650223578585 valid 3.227819543273934e-08
# Training vs. Validation Loss {'Training': 0.0012049650223578585, 'Validation': 3.227819543273934e-08} 148
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 148
# Epoch 148:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009265369716331406 valid 1.1737528658419304e-08
# Training vs. Validation Loss {'Training': 0.0009265369716331406, 'Validation': 1.1737528658419304e-08} 149
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 149
# Epoch 149:
# Accuracy train:1.0, val:1.0
# LOSS train 0.002227880036514307 valid 2.448363756863286e-07
# Training vs. Validation Loss {'Training': 0.002227880036514307, 'Validation': 2.448363756863286e-07} 150
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 150
# Epoch 150:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0017558223333461835 valid 6.547336324384918e-08
# Training vs. Validation Loss {'Training': 0.0017558223333461835, 'Validation': 6.547336324384918e-08} 151
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 151
# Epoch 151:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00045811871101382923 valid 9.096566645238315e-08
# Training vs. Validation Loss {'Training': 0.00045811871101382923, 'Validation': 9.096566645238315e-08} 152
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 152
# Epoch 152:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001537697146886785 valid 3.319518263685731e-08
# Training vs. Validation Loss {'Training': 0.001537697146886785, 'Validation': 3.319518263685731e-08} 153
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 153
# Epoch 153:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0021277010331743895 valid 1.1040595135561112e-07
# Training vs. Validation Loss {'Training': 0.0021277010331743895, 'Validation': 1.1040595135561112e-07} 154
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 154
# Epoch 154:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0007083797170253092 valid 7.922821373321872e-08
# Training vs. Validation Loss {'Training': 0.0007083797170253092, 'Validation': 7.922821373321872e-08} 155
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 155
# Epoch 155:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00018266480642618413 valid 5.0434658022551886e-08
# Training vs. Validation Loss {'Training': 0.00018266480642618413, 'Validation': 5.0434658022551886e-08} 156
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 156
# Epoch 156:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00015574208464386174 valid 5.611995907300455e-08
# Training vs. Validation Loss {'Training': 0.00015574208464386174, 'Validation': 5.611995907300455e-08} 157
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 157
# Epoch 157:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00040368784038946615 valid 6.822413396616429e-08
# Training vs. Validation Loss {'Training': 0.00040368784038946615, 'Validation': 6.822413396616429e-08} 158
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 158
# Epoch 158:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00034051676450985724 valid 3.1177803860006094e-08
# Training vs. Validation Loss {'Training': 0.00034051676450985724, 'Validation': 3.1177803860006094e-08} 159
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 159
# Epoch 159:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004608528208223106 valid 2.8243405494685284e-08
# Training vs. Validation Loss {'Training': 0.0004608528208223106, 'Validation': 2.8243405494685284e-08} 160
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 160
# Epoch 160:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005167480505103109 valid 3.2644982580402136e-08
# Training vs. Validation Loss {'Training': 0.0005167480505103109, 'Validation': 3.2644982580402136e-08} 161
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 161
# Epoch 161:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001961276264760651 valid 3.7413312789716166e-08
# Training vs. Validation Loss {'Training': 0.0001961276264760651, 'Validation': 3.7413312789716166e-08} 162
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 162
# Epoch 162:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00027072652689715443 valid 2.1090858837169435e-08
# Training vs. Validation Loss {'Training': 0.00027072652689715443, 'Validation': 2.1090858837169435e-08} 163
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 163
# Epoch 163:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.0006114314868076084 valid 4.0897935909684364e-08
# Training vs. Validation Loss {'Training': 0.0006114314868076084, 'Validation': 4.0897935909684364e-08} 164
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 164
# Epoch 164:
# ...
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 243
# Epoch 243:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.003403297787848203 valid 6.969157285451589e-09
# Training vs. Validation Loss {'Training': 0.003403297787848203, 'Validation': 6.969157285451589e-09} 244
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 244
# Epoch 244:
# Accuracy train:1.0, val:1.0
# LOSS train 9.512272176929552e-05 valid 5.685364452727544e-09
# Training vs. Validation Loss {'Training': 9.512272176929552e-05, 'Validation': 5.685364452727544e-09} 245
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 245
# Epoch 245:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00026163460639002284 valid 7.152555675942879e-09
# Training vs. Validation Loss {'Training': 0.00026163460639002284, 'Validation': 7.152555675942879e-09} 246
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 246
# Epoch 246:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00038285321647416975 valid 6.969157353773006e-09
# Training vs. Validation Loss {'Training': 0.00038285321647416975, 'Validation': 6.969157353773006e-09} 247
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 247
# Epoch 247:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0032879170029313323 valid 2.200786151608834e-09
# Training vs. Validation Loss {'Training': 0.0032879170029313323, 'Validation': 2.200786151608834e-09} 248
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 248
# Epoch 248:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00038247445147199244 valid 1.650589818670876e-09
# Training vs. Validation Loss {'Training': 0.00038247445147199244, 'Validation': 1.650589818670876e-09} 249
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 249
# Epoch 249:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00017656838636762964 valid 1.283792217831293e-09
# Training vs. Validation Loss {'Training': 0.00017656838636762964, 'Validation': 1.283792217831293e-09} 250
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 250
# Epoch 250:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00014187089888354856 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 0.00014187089888354856, 'Validation': 5.501966745450423e-10} 251
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 251
# Epoch 251:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001181957232342749 valid 7.335955432862508e-10
# Training vs. Validation Loss {'Training': 0.0001181957232342749, 'Validation': 7.335955432862508e-10} 252
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 252
# Epoch 252:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00023378668744437428 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 0.00023378668744437428, 'Validation': 1.833989029019169e-10} 253
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 253
# Epoch 253:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0005292243079407418 valid 4.951769797619713e-09
# Training vs. Validation Loss {'Training': 0.0005292243079407418, 'Validation': 4.951769797619713e-09} 254
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 254
# Epoch 254:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0019333082638392323 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 0.0019333082638392323, 'Validation': 5.501966745450423e-10} 255
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 255
# Epoch 255:
# Accuracy train:0.9994791746139526, val:1.0
# LOSS train 0.001771424767298413 valid 1.2104325336919759e-08
# Training vs. Validation Loss {'Training': 0.001771424767298413, 'Validation': 1.2104325336919759e-08} 256
# Training vs. Validation accuracy {'Training': 0.9994791746139526, 'Validation': 1.0} 256
# Epoch 256:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00033427187897909033 valid 3.851376106922544e-09
# Training vs. Validation Loss {'Training': 0.00033427187897909033, 'Validation': 3.851376106922544e-09} 257
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 257
# Epoch 257:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00019071948885773793 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 0.00019071948885773793, 'Validation': 5.501966745450423e-10} 258
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 258
# Epoch 258:
# Accuracy train:1.0, val:1.0
# LOSS train 7.466266729968159e-05 valid 1.28379228615271e-09
# Training vs. Validation Loss {'Training': 7.466266729968159e-05, 'Validation': 1.28379228615271e-09} 259
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 259
# Epoch 259:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003023794467379067 valid 1.8339888923763352e-09
# Training vs. Validation Loss {'Training': 0.0003023794467379067, 'Validation': 1.8339888923763352e-09} 260
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 260
# Epoch 260:
# Accuracy train:1.0, val:1.0
# LOSS train 7.927730857322975e-05 valid 2.567583889091251e-09
# Training vs. Validation Loss {'Training': 7.927730857322975e-05, 'Validation': 2.567583889091251e-09} 261
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 261
# Epoch 261:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0012833209469960138 valid 1.1003934174115015e-09
# Training vs. Validation Loss {'Training': 0.0012833209469960138, 'Validation': 1.1003934174115015e-09} 262
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 262
# Epoch 262:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000194947700862258 valid 2.0173878977603774e-09
# Training vs. Validation Loss {'Training': 0.000194947700862258, 'Validation': 2.0173878977603774e-09} 263
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 263
# Epoch 263:
# Accuracy train:1.0, val:1.0
# LOSS train 7.623102367896688e-05 valid 2.017387931921086e-09
# Training vs. Validation Loss {'Training': 7.623102367896688e-05, 'Validation': 2.017387931921086e-09} 264
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 264
# Epoch 264:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00011555071640145798 valid 1.1003934174115015e-09
# Training vs. Validation Loss {'Training': 0.00011555071640145798, 'Validation': 1.1003934174115015e-09} 265
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 265
# Epoch 265:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00019312968427698252 valid 1.6505900236351268e-09
# Training vs. Validation Loss {'Training': 0.00019312968427698252, 'Validation': 1.6505900236351268e-09} 266
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 266
# Epoch 266:
# Accuracy train:1.0, val:1.0
# LOSS train 9.744012262539552e-05 valid 7.335955774469591e-10
# Training vs. Validation Loss {'Training': 9.744012262539552e-05, 'Validation': 7.335955774469591e-10} 267
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 267
# Epoch 267:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000276872359776803 valid 2.017387931921086e-09
# Training vs. Validation Loss {'Training': 0.000276872359776803, 'Validation': 2.017387931921086e-09} 268
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 268
# Epoch 268:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016834555039224597 valid 1.1003934174115015e-09
# Training vs. Validation Loss {'Training': 0.00016834555039224597, 'Validation': 1.1003934174115015e-09} 269
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 269
# Epoch 269:
# Accuracy train:1.0, val:1.0
# LOSS train 9.390675460944446e-05 valid 1.8339888923763352e-09
# Training vs. Validation Loss {'Training': 9.390675460944446e-05, 'Validation': 1.8339888923763352e-09} 270
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 270
# Epoch 270:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001314937961787166 valid 1.4671911548939183e-09
# Training vs. Validation Loss {'Training': 0.0001314937961787166, 'Validation': 1.4671911548939183e-09} 271
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 271
# Epoch 271:
# Accuracy train:1.0, val:1.0
# LOSS train 9.220763548907958e-05 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 9.220763548907958e-05, 'Validation': 1.833989029019169e-10} 272
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 272
# Epoch 272:
# Accuracy train:1.0, val:1.0
# LOSS train 7.128510308263003e-05 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 7.128510308263003e-05, 'Validation': 5.501966745450423e-10} 273
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 273
# Epoch 273:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0001418225097339724 valid 1.283792217831293e-09
# Training vs. Validation Loss {'Training': 0.0001418225097339724, 'Validation': 1.283792217831293e-09} 274
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 274
# Epoch 274:
# Accuracy train:1.0, val:1.0
# LOSS train 9.651586443363651e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 9.651586443363651e-05, 'Validation': 3.667978058038338e-10} 275
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 275
# Epoch 275:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00014578126817651102 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 0.00014578126817651102, 'Validation': 1.833989029019169e-10} 276
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 276
# Epoch 276:
# Accuracy train:1.0, val:1.0
# LOSS train 8.1153463218205e-05 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 8.1153463218205e-05, 'Validation': 1.833989029019169e-10} 277
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 277
# Epoch 277:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003131459620361691 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 0.0003131459620361691, 'Validation': 1.833989029019169e-10} 278
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 278
# Epoch 278:
# Accuracy train:1.0, val:1.0
# LOSS train 5.134730632327944e-05 valid 0.0
# Training vs. Validation Loss {'Training': 5.134730632327944e-05, 'Validation': 0.0} 279
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 279
# Epoch 279:
# Accuracy train:1.0, val:1.0
# LOSS train 8.657728244069555e-05 valid 0.0
# Training vs. Validation Loss {'Training': 8.657728244069555e-05, 'Validation': 0.0} 280
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 280
# Epoch 280:
# Accuracy train:1.0, val:1.0
# LOSS train 8.776720584258157e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 8.776720584258157e-05, 'Validation': 3.667978058038338e-10} 281
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 281
# Epoch 281:
# Accuracy train:1.0, val:1.0
# LOSS train 4.021239072068047e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 4.021239072068047e-05, 'Validation': 3.667978058038338e-10} 282
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 282
# Epoch 282:
# Accuracy train:1.0, val:1.0
# LOSS train 7.04431794065948e-05 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 7.04431794065948e-05, 'Validation': 1.833989029019169e-10} 283
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 283
# Epoch 283:
# Accuracy train:1.0, val:1.0
# LOSS train 3.409914381879986e-05 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 3.409914381879986e-05, 'Validation': 5.501966745450423e-10} 284
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 284
# Epoch 284:
# Accuracy train:1.0, val:1.0
# LOSS train 5.996038018511266e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 5.996038018511266e-05, 'Validation': 3.667978058038338e-10} 285
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 285
# Epoch 285:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00016943232914812256 valid 0.0
# Training vs. Validation Loss {'Training': 0.00016943232914812256, 'Validation': 0.0} 286
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 286
# Epoch 286:
# Accuracy train:1.0, val:1.0
# LOSS train 3.6110433551191555e-05 valid 0.0
# Training vs. Validation Loss {'Training': 3.6110433551191555e-05, 'Validation': 0.0} 287
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 287
# Epoch 287:
# Accuracy train:1.0, val:1.0
# LOSS train 8.568722689439312e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 8.568722689439312e-05, 'Validation': 3.667978058038338e-10} 288
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 288
# Epoch 288:
# Accuracy train:1.0, val:1.0
# LOSS train 4.840508008611503e-05 valid 1.283792217831293e-09
# Training vs. Validation Loss {'Training': 4.840508008611503e-05, 'Validation': 1.283792217831293e-09} 289
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 289
# Epoch 289:
# Accuracy train:1.0, val:1.0
# LOSS train 4.014140543399473e-05 valid 0.0
# Training vs. Validation Loss {'Training': 4.014140543399473e-05, 'Validation': 0.0} 290
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 290
# Epoch 290:
# Accuracy train:1.0, val:1.0
# LOSS train 5.542090643828601e-05 valid 3.667978058038338e-10
# Training vs. Validation Loss {'Training': 5.542090643828601e-05, 'Validation': 3.667978058038338e-10} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 291
# Epoch 291:
# Accuracy train:1.0, val:1.0
# LOSS train 4.497198809261249e-05 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 4.497198809261249e-05, 'Validation': 5.501966745450423e-10} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 292
# Epoch 292:
# Accuracy train:1.0, val:1.0
# LOSS train 6.945663523675687e-05 valid 1.1003932807686676e-09
# Training vs. Validation Loss {'Training': 6.945663523675687e-05, 'Validation': 1.1003932807686676e-09} 293
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 293
# Epoch 293:
# Accuracy train:1.0, val:1.0
# LOSS train 1.7731651251295943e-05 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 1.7731651251295943e-05, 'Validation': 5.501966745450423e-10} 294
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 294
# Epoch 294:
# Accuracy train:1.0, val:1.0
# LOSS train 7.239738081092166e-05 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 7.239738081092166e-05, 'Validation': 1.833989029019169e-10} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 295
# Epoch 295:
# Accuracy train:1.0, val:1.0
# LOSS train 2.906940761082666e-05 valid 1.833989029019169e-10
# Training vs. Validation Loss {'Training': 2.906940761082666e-05, 'Validation': 1.833989029019169e-10} 296
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 296
# Epoch 296:
# Accuracy train:1.0, val:1.0
# LOSS train 5.128936369451035e-05 valid 5.501966745450423e-10
# Training vs. Validation Loss {'Training': 5.128936369451035e-05, 'Validation': 5.501966745450423e-10} 297
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 297
# Epoch 297:
# Accuracy train:1.0, val:1.0
# LOSS train 3.859189703442345e-05 valid 0.0
# Training vs. Validation Loss {'Training': 3.859189703442345e-05, 'Validation': 0.0} 298
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 298
# Epoch 298:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0020570115807032607 valid 5.850408103268679e-08
# Training vs. Validation Loss {'Training': 0.0020570115807032607, 'Validation': 5.850408103268679e-08} 299
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 299
# Epoch 299:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0027036044852764007 valid 0.0
# Training vs. Validation Loss {'Training': 0.0027036044852764007, 'Validation': 0.0} 300
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 300
# tensor(1.)

# %%
list_label = label_dict_from_config_file("../hand_gesture.yaml")
DATA_FOLDER_PATH="../data_collection/data2/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    
    preds = network(test_input)
    acc_test.update(preds, test_label)

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:1.0
# ========================================================================
